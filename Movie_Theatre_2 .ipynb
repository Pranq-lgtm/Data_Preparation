# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranq-lgtm/Data_Preparation/blob/main/Movie_Theatre_2%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
data=pd.read_csv("sample_data/movie theatre.csv")

# %%
data.head()
# Out:
#                          Timestamp  \
# 0  2024/07/11 11:39:07 am GMT+5:30
# 1  2024/07/11 11:40:19 am GMT+5:30
# 2  2024/07/11 11:46:55 am GMT+5:30
# 3   2024/07/18 9:42:23 am GMT+5:30
# 4  2024/07/11 11:39:07 am GMT+5:30
#
#   Which genres of movie do you like the most?  \
# 0                                      Horror
# 1                                    Thriller
# 2                                       Drama
# 3                                      Horror
# 4                                      Horror
#
#   Which movie theatre do you like visiting the most   \
# 0                                               Inox
# 1                                                Pvr
# 2                                               Inox
# 3                                               Inox
# 4                                               Inox
#
#    How many movie have you are in past three months in movie theatre   \
# 0                                                4.0
# ...

# %%
data.sample(10)
# Out:
#                           Timestamp  \
# 2   2024/07/11 11:46:55 am GMT+5:30
# 0   2024/07/11 11:39:07 am GMT+5:30
# 21                              NaN
# 16  2024/07/11 11:39:07 am GMT+5:30
# 17  2024/07/11 11:40:19 am GMT+5:30
# 9   2024/07/11 11:40:19 am GMT+5:30
# 12  2024/07/11 11:39:07 am GMT+5:30
# 22                              NaN
# 5   2024/07/11 11:40:19 am GMT+5:30
# 7    2024/07/18 9:42:23 am GMT+5:30
#
#    Which genres of movie do you like the most?  \
# 2                                        Drama
# 0                                       Horror
# 21                                         NaN
# 16                                      Horror
# 17                                    Thriller
# 9                                     Thriller
# 12                                      Horror
# 22                                         NaN
# 5                                     Thriller
# 7                                       Horror
#
# ...

# %%
data.columns
# Out:
# Index(['Timestamp', 'Which genres of movie do you like the most?',
#        'Which movie theatre do you like visiting the most ',
#        'How many movie have you are in past three months in movie theatre ',
#        'Do  you like to buy beverages and popcorns from movie theatre ',
#        'In which row do you like to sit and watch movie ',
#        'Your take on should there be more movie theatres in your locality or not ',
#        'Do you like to watch movie with friends and family or alone',
#        'If you have watched the recent movie 'kalki 2898 AD' give your review about the movie ',
#        'Describe your reaction after first visiting a movie theatre ',
#        'Do you like to watch 3D movies(if yes describe your reaction)'],
#       dtype='object')

# %%
data.shape
# Out:
# (26, 11)

# %%
print(data)
# Out:
#                           Timestamp  \
# 0   2024/07/11 11:39:07 am GMT+5:30
# 1   2024/07/11 11:40:19 am GMT+5:30
# 2   2024/07/11 11:46:55 am GMT+5:30
# 3    2024/07/18 9:42:23 am GMT+5:30
# 4   2024/07/11 11:39:07 am GMT+5:30
# 5   2024/07/11 11:40:19 am GMT+5:30
# 6   2024/07/11 11:46:55 am GMT+5:30
# 7    2024/07/18 9:42:23 am GMT+5:30
# 8   2024/07/11 11:39:07 am GMT+5:30
# 9   2024/07/11 11:40:19 am GMT+5:30
# 10  2024/07/11 11:46:55 am GMT+5:30
# 11   2024/07/18 9:42:23 am GMT+5:30
# 12  2024/07/11 11:39:07 am GMT+5:30
# 13  2024/07/11 11:40:19 am GMT+5:30
# 14  2024/07/11 11:46:55 am GMT+5:30
# 15   2024/07/18 9:42:23 am GMT+5:30
# 16  2024/07/11 11:39:07 am GMT+5:30
# 17  2024/07/11 11:40:19 am GMT+5:30
# 18  2024/07/11 11:46:55 am GMT+5:30
# 19                              NaN
# 20                              NaN
# 21                              NaN
# 22                              NaN
# 23                              NaN
# 24                              NaN
# ...

# %%
print(data[5:10])
# Out:
#                          Timestamp  \
# 5  2024/07/11 11:40:19 am GMT+5:30
# 6  2024/07/11 11:46:55 am GMT+5:30
# 7   2024/07/18 9:42:23 am GMT+5:30
# 8  2024/07/11 11:39:07 am GMT+5:30
# 9  2024/07/11 11:40:19 am GMT+5:30
#
#   Which genres of movie do you like the most?  \
# 5                                    Thriller
# 6                                       Drama
# 7                                      Horror
# 8                                      Horror
# 9                                    Thriller
#
#   Which movie theatre do you like visiting the most   \
# 5                                                Pvr
# 6                                               Inox
# 7                                               Inox
# 8                                               Inox
# 9                                                Pvr
#
#    How many movie have you are in past three months in movie theatre   \
# 5                                                4.0
# ...

# %%
sliced_data=data[5:10]

# %%
print(sliced_data)
# Out:
#                          Timestamp  \
# 5  2024/07/11 11:40:19 am GMT+5:30
# 6  2024/07/11 11:46:55 am GMT+5:30
# 7   2024/07/18 9:42:23 am GMT+5:30
# 8  2024/07/11 11:39:07 am GMT+5:30
# 9  2024/07/11 11:40:19 am GMT+5:30
#
#   Which genres of movie do you like the most?  \
# 5                                    Thriller
# 6                                       Drama
# 7                                      Horror
# 8                                      Horror
# 9                                    Thriller
#
#   Which movie theatre do you like visiting the most   \
# 5                                                Pvr
# 6                                               Inox
# 7                                               Inox
# 8                                               Inox
# 9                                                Pvr
#
#    How many movie have you are in past three months in movie theatre   \
# 5                                                4.0
# ...

# %%
specific_data=data[["Timestamp"]]

# %%
print(specific_data.head(10))
# Out:
#                          Timestamp
# 0  2024/07/11 11:39:07 am GMT+5:30
# 1  2024/07/11 11:40:19 am GMT+5:30
# 2  2024/07/11 11:46:55 am GMT+5:30
# 3   2024/07/18 9:42:23 am GMT+5:30
# 4  2024/07/11 11:39:07 am GMT+5:30
# 5  2024/07/11 11:40:19 am GMT+5:30
# 6  2024/07/11 11:46:55 am GMT+5:30
# 7   2024/07/18 9:42:23 am GMT+5:30
# 8  2024/07/11 11:39:07 am GMT+5:30
# 9  2024/07/11 11:40:19 am GMT+5:30

# %%
data['How many movie have you are in past three months in movie theatre '].value_counts()
# Out:
# How many movie have you are in past three months in movie theatre
# 1.000000    7
# 4.000000    3
# 6.000000    3
# 2.000000    3
# 5.000000    2
# 3.000000    2
# 7.000000    1
# 3.263158    1
# 2.104020    1
# Name: count, dtype: int64

# %%
sum_data=data['How many movie have you are in past three months in movie theatre '].sum()

# %%
mean_data=data['How many movie have you are in past three months in movie theatre '].mean()

# %%
median_data=data['How many movie have you are in past three months in movie theatre '].median()

# %%
print("sum:",sum_data,"\nmean:",mean_data,"\nmedian:",median_data)
# Out:
# sum: 71.36717799600001
# mean: 3.102920782434783
# median: 3.0

# %%
min_data=data['How many movie have you are in past three months in movie theatre '].min()

# %%
max_data=data['How many movie have you are in past three months in movie theatre '].max()

# %%
print("Minimum:",min_data,"\nMaximum:",max_data)
# Out:
# Minimum: 1.0
# Maximum: 7.0

# %%
newcols={"How many movie have you are in past three months in movie theatre":"movies watched",
"which movie theatre do you like visting the most":"movie theatre"}

# %%
data.rename(columns=newcols,inplace=True)

# %%
print(data.head())

# %%
cols=data.columns

# %%
print(cols)

# %%
cols=cols[1:5]

# %%
data1=data[cols]

# %%
data["total_values"]=data1[cols].sum(axis=1)
